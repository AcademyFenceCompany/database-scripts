# %%
import pandas as pd

# %%
address_original_df = pd.read_csv("C:\\Users\\WebDev4\\Desktop\\afc_website\\db-scripts\\database-scripts\\customer_transformations\\address\\cust_addresses_2.csv")
address_original_df.head()
# Out:
# C:\Users\WebDev4\AppData\Local\Temp\ipykernel_30824\3739178069.py:1: DtypeWarning: Columns (6,15,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   address_original_df = pd.read_csv("C:\\Users\\WebDev4\\Desktop\\afc_website\\db-scripts\\database-scripts\\customer_transformations\\address\\cust_addresses_2.csv")
#    addr_id  cust_id_fk  addr_shipping  addr_billing            addr_name  \
# 0        2           1              1             0              JK Test
# 1        3           1              1             1            Jared 123
# 2        4       24786              0             1     Xy Web Solutions
# 3    32031       27836              0             1         Artur Marnik
# 4        7           3              1             1  Nextcarrier Telecom
#
#   addr_company      addr_contact      addr_address     addr_address2  \
# 0          NaN     Jared Kazimir      321 Address2               NaN
# ...

# %%
address_transform_df = pd.DataFrame(columns=["original_customer_id", "address_contact", "address_1", "address_2", "city", "state", "zipcode", "shipping_flag", "billing_flag"])
address_transform_df

# %%
# address_transform_df = address_original_df.rename(columns={"cust_id_fk": "original_customer_id", "addr_address" : "address_1", "addr_address2" : "address_2", 
# "addr_city" : "city", "addr_state" : "state", "addr_postcode" : "zipcode",
# "addr_shipping" : "shipping_flag", "addr_billing" : "billing_flag"})

address_transform_df["original_customer_id"] = address_original_df["cust_id_fk"]
address_transform_df["address_1"] = address_original_df["addr_address"] 
address_transform_df["address_2"] = address_original_df["addr_address2"]
address_transform_df["city"] = address_original_df["addr_city"]
address_transform_df["state"] = address_original_df["addr_state"]
address_transform_df["zipcode"] = address_original_df["addr_postcode"]
address_transform_df["shipping_flag"] = address_original_df["addr_shipping"]
address_transform_df["billing_flag"] = address_original_df["addr_billing"]


address_transform_df

# %%
address_transform_df["address_contact"] = address_original_df["addr_contact"] if address_original_df["addr_contact"].any(skipna=True) else address_original_df["addr_name"]

address_transform_df.head()

# %%
address_transform_df = address_transform_df.fillna('NULL')
address_transform_df

# %%
address_transform_df.to_csv("C:\\Users\\WebDev4\\Desktop\\afc_website\\db-scripts\\database-scripts\\database_csvs\\customer_info\\customer_addresses_trans_2.csv", index=False)
